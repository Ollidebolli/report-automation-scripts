# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('Individual_scoreboard_template.csv')

# %%
Alexandra = ['Tim Hatcher','Conor Gribbin','Adriaan Welgraven','Flavio La Terza','Ouiam Haddou','Hamza BOULLOUS','Girish Kini','Raul Hernandez Seda']
Veronica = ['Ayse Feyzanur Ermurat','Raffaele Talarico','Daniele Sarno','Francesc Callejas','Francesco Bastianello','Hur Bakan','Jorge Sanchez','Josefina Furrer','Josep Martin','Luca Fatigati','Marco De Rossi','Selene Hernandez','Jonathan Soret','Raquel Lopez']
Alaa = ['Abdollah MOSTAFA','Ahmed ABDELAAL','Mariam YEHIA','Mohamed SADAT','Monica YOUSSEF','Obada SAYED','Samar ALEZABY','Clotilde Demeyer','Constance de Kertanguy','Ilias Bensaid','Vianney Dufour','Kim Do Tri']

# %%
Alexandra = sorted(Alexandra)
Veronica = sorted(Veronica)
Alaa = sorted(Alaa)

# %%
lol = Alexandra + Veronica + Alaa

# %%
df = pd.DataFrame(index=range(len(lol)),columns = test.columns)
df['Presales'] = lol

# %%
df.to_csv('Individual_scoreboard_template.csv')

# %%
df
# Out:
#    Unnamed: 0 Unnamed: 0.1                Presales  \
# 0         NaN          NaN       Adriaan Welgraven
# 1         NaN          NaN           Conor Gribbin
# 2         NaN          NaN         Flavio La Terza
# 3         NaN          NaN             Girish Kini
# 4         NaN          NaN          Hamza BOULLOUS
# 5         NaN          NaN            Ouiam Haddou
# 6         NaN          NaN     Raul Hernandez Seda
# 7         NaN          NaN             Tim Hatcher
# 8         NaN          NaN   Ayse Feyzanur Ermurat
# 9         NaN          NaN           Daniele Sarno
# 10        NaN          NaN       Francesc Callejas
# 11        NaN          NaN   Francesco Bastianello
# 12        NaN          NaN               Hur Bakan
# 13        NaN          NaN          Jonathan Soret
# 14        NaN          NaN           Jorge Sanchez
# 15        NaN          NaN         Josefina Furrer
# 16        NaN          NaN            Josep Martin
# ...

# %%
# Out:
# array(['Vianney Dufour', 'Ouiam Haddou', 'Ilias Bensaid',
#        'Glenn Van Eijk', 'Hur Bakan', 'Kim Do Tri', 'Flavio La Terza',
#        'Girish Kini', 'Adriaan Welgraven', 'Samar ALEZABY',
#        'Josep Martin', 'Conor Gribbin', 'Monica YOUSSEF', 'Mariam YEHIA',
#        'Mohamed SADAT', 'Abdollah MOSTAFA', 'Daniele Sarno',
#        'Hamza BOULLOUS', 'Tim Hatcher', 'Selene Hernandez',
#        'Clotilde Demeyer', 'Josefina Furrer', 'Marco De Rossi',
#        'Obada SAYED', 'Luca Fatigati', 'Jorge Sanchez', 'Ahmed ABDELAAL',
#        'Ayse Feyzanur Ermurat', 'Jonathan Soret', 'Raquel Lopez',
#        'Raul Hernandez Seda'], dtype=object)

# %%
['']
